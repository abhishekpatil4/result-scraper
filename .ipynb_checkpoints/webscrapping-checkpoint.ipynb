# %%
from bs4 import BeautifulSoup

# %%
# !pip install selenium
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting selenium
#   Downloading selenium-4.16.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting urllib3<3,>=1.26 (from urllib3[socks]<3,>=1.26->selenium)
#   Downloading urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.24.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.9/site-packages (from selenium) (2022.6.15)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.9/site-packages (from trio~=0.17->selenium) (21.4.0)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.9/site-packages (from trio~=0.17->selenium) (3.3)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.3.0)
# Collecting exceptiongroup (from trio~=0.17->selenium)
#   Downloading exceptiongroup-1.2.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.9/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.16.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 633.6 kB/s eta 0:00:0000:010:01
# Downloading trio-0.24.0-py3-none-any.whl (460 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.2/460.2 kB 555.7 kB/s eta 0:00:00a 0:00:01
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading urllib3-2.1.0-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.6/104.6 kB 511.7 kB/s eta 0:00:00a 0:00:01
# Downloading exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: sortedcontainers, wsproto, urllib3, outcome, exceptiongroup, trio, trio-websocket, selenium
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.11
#     Uninstalling urllib3-1.25.11:
#       Successfully uninstalled urllib3-1.25.11
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-auth 2.22.0 requires urllib3<2.0, but you have urllib3 2.1.0 which is incompatible.
# requests 2.28.1 requires urllib3<1.27,>=1.21.1, but you have urllib3 2.1.0 which is incompatible.
# tensorflow 2.13.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.0 which is incompatible.
# tensorflowjs 3.18.0 requires packaging~=20.9, but you have packaging 21.3 which is incompatible.
# tflite-model-maker 0.3.4 requires flatbuffers==1.12, but you have flatbuffers 23.5.26 which is incompatible.
# tflite-model-maker 0.3.4 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 2.1.0 which is incompatible.
# tflite-model-maker-nightly 0.3.5.dev202205040508 requires flatbuffers==1.12, but you have flatbuffers 23.5.26 which is incompatible.
# tflite-model-maker-nightly 0.3.5.dev202205040508 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 2.1.0 which is incompatible.
# Successfully installed exceptiongroup-1.2.0 outcome-1.3.0.post0 selenium-4.16.0 sortedcontainers-2.4.0 trio-0.24.0 trio-websocket-0.11.1 urllib3-2.1.0 wsproto-1.2.0
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
from selenium import webdriver

# %%
import time

# %%
#You need to have Chrome driver downloaded in your computer
#http://chromedriver.chromium.org/

#You need to have driver corresponding to your Google Chrome browser or update browser
from selenium.webdriver.common.by import By

# %%
#this generates USNs from 1 to 330 
#If your branch is different then you can change the branch code such as BEC,BCV etc
usns=[]
for i in range(1,330):
    if i<=9:
        usn='01FE20BCS00'+str(i)
    elif i>=10 and i<=99:
        usn='01FE20BCS0'+str(i)
    else:
        usn='01FE20BCS'+str(i)
    usns.append(usn)
#For Diploma students
for i in range(1,36):
    if i<=9:
        usn='01FE21BCS40'+str(i)
    elif i>=10 and i<=99:
        usn='01FE21BCS4'+str(i)
    usns.append(usn)

# %% [markdown]
# ### Run the cell below and wait until Google Chrome opens

# %%
url="https://eresults.kletech.ac.in/index.php"

#This is the path name of chrome driver on my PC
# driver = webdriver.Chrome("/Users/anandsagar/Downloads/chromedriver_mac_arm64 (2)/chromedriver")
driver = webdriver.Chrome()

driver.get(url)
driver.maximize_window()

# %% [markdown]
# ### When website Opens then change the captcha below and run the cell
#
# ### My college website has a glitch that its captcha doesn't change if we navigate back on the website

# %%
#put the captcha as shown in website and run this cell
captcha="W4L23" #this was the current captcha when I was using

# %%
file=open('result7_sgpa.csv','a') #This is the file in which I am storing Name and SGPA

# %%
#For each USN I am scrapping the details
for username in usns:
    driver.find_element(by=By.NAME,value="usn").send_keys(username)
    driver.find_element(by=By.NAME,value="osolCatchaTxt").send_keys(captcha)

    # driver.find_element_by_formaction("index.php?option=com_examresult&task=getResult").click()
    driver.find_element(By.XPATH, '//button[text()="Result"]').click()
    
    #I am handling the exception because there are certain USNs whose result is not declared or some USNs don't exist
    try:
        #This //div..... may change depending on what you are trying to scrap
        name=driver.find_element(By.XPATH,'//div[contains(@class,"uk-card uk-card-body stu-data stu-data1")]')
        print(name.text) #optional
        
    except:
        print("Error in name")
    
    try:
        sgpa=driver.find_element(By.XPATH,'//div[contains(@class,"uk-card uk-card-default uk-card-body credits-sec3")]')
        print(sgpa.text[5:]) #Since the extracted data has SGPA as suffix but we need to store only numerical part
        file.write('\n'+(name.text)+','+(sgpa.text[5:]))
    except:
        print("Error in sgpa")
        
    driver.back() #navigating back by clicking back button

    driver.find_element(by=By.NAME,value="usn").clear() #clearing the already filled detail
    driver.find_element(by=By.NAME,value="osolCatchaTxt").clear() #Clearing the CAPTCHA field as it will be Entered aagain
# Out:
# ASHRITA ANAND GAONKAR
# 7.17
# SOUMYA KOTRESH KATAGIHALLI
# 8.67
# ADITYA DILIP JADHAV
# Error in sgpa
# PRERANA SATYANARAYANA MURTHY MALAGI
# 8.34
# AKSHATA PARAMESH BADNI
# Error in sgpa
# NEHA PATIL
# 8.84
# LOHIT VINAYAK GANGOLLI
# Error in sgpa
# KONKATHI RITHIN KUMAR
# 2.15
# RANJITA PRASHANT HEGDE
# 8.50
# SRISHTI ANIL KADAM
# 8.75
# ULHAS S KALASA
# 8.34
# PRAVEEN VISHWA KULLI
# 8.84
# NIKHITA BALAJI NADAKARNI
# Error in sgpa
# SANDEEP SADANAND HALKATTI
# 8.34
# SAHANA G AIDNAL
# 9.17
# SRUSHTI PRAKASH NAYAK
# 8.50
# ANANYA M PATIL
# 8.34
# CHIRAG SANDEEP METGUD
# Error in sgpa
# SHREYA B DEVAGIRI
# 9.50
# AJAY BASAVARAJ POLIS GOWDAR
# 0.00
# AISHWARYA GANIGER
# 7.75
# Error in name
# Error in sgpa
# GANESHDARSHAN MALAGI
# Error in sgpa
# ANEESH SUDHEENDRA VAIDYA
# Error in sgpa
# SUSHIR RAMESH METI
# 8.00
# S SAMHITH KUMAR
# Error in sgpa
# RANJEETA BASAVARAJ ANGADI
# Error in sgpa
# H VARUN
# Error in sgpa
# AMIT SAKRI
# 7.75
# Error in name
# Error in sgpa
# AMITHA CHOWDHARY NANDINA
# 8.00
# VIKAS RAJENDRA HUKKERI
# 6.00
# ANIL JAYAPPA ARIKATTI
# Error in sgpa
# MOVVA DHANUSH
# 0.63
# PAMALI SNEHA KRISHNAMURTI
# 9.00
# JAGADISH B BASAPUR
# 8.34
# ABHINANDAN GURUPRASAD HIREMATH
# 8.67
# DHARESH AMARASHETTY
# Error in sgpa
# AKHIL VENKATESH SHANBHAG
# 8.84
# JYOTHI IRANNA MIRJE
# Error in sgpa
# ATHARV V KADOLE
# Error in sgpa
# Error in name
# Error in sgpa
# SUSHMITA KORISHETTY
# 9.00
# ANIKET ARVIND AMBEKAR
# Error in sgpa
# CHAITRA GIRISH HEGDE
# 8.34
# ANUSHA N TANDUR
# 7.34
# ABHISHEK ASHOK PATIL
# 9.50
# YAJAS SARATH MENON
# Error in sgpa
# RITESH MAHESH BAGEWADI
# 3.41
# SHWETA HONNAPPANAVAR
# Error in sgpa
# NITHYA M M
# Error in sgpa
# AKSHATH ANAND MUGAD
# 8.17
# Error in name
# Error in sgpa
# ATHAR MUJTABA
# 8.50
# KARTHIK HIREMATH
# 9.00
# SAANJALI BELGAVI
# Error in sgpa
# HRISHIKESH V VASTRAD
# Error in sgpa
# ARYA MAHANTESH KINAGI
# 8.34
# ABHISHEK KUMAR
# 8.67
# SANGAMESH
# 7.50
# ARPITA G HEGDE
# 8.67
# ADITYA J GOVANAKOPPA
# 7.17
# KUSHAGRA TOMAR
# 9.34
# SUMEDH KULKARNI
# 9.00
# BAGAL APOORV SHIVAJI
# 8.67
# REEMAK DAWE
# 2.78
# Error in name
# Error in sgpa
# SHASHANK HEGDE
# 8.75
# Error in name
# Error in sgpa
# ANANT ALIAS SUDEEP SUHAS PINGULKAR
# 7.50
# SIRI K VENKATESH
# 9.34
# SPARSHA J SHETTY
# 8.84
# ROHAN KURDEKAR
# 8.50
# GURAV CHINMAY SUNIL
# 8.67
# MITHILESH YADAWAD
# 8.84
# RAKSHITA C BANDI
# 8.34
# GURUPRASAD D GHALIGI
# 8.17
# PRIYA A JADEKAR
# 9.25
# SAGAR AMBASA KABADI
# 8.00
# RITVIK S CHUNAMARI
# Error in sgpa
# P S ADITYA
# 8.17
# GURURAJ SUDHAKAR HEGADE
# 5.00
# NEHA JAIN
# 8.84
# VIVEK PRAKASH MARAKUMBI
# 9.50
# Error in name
# Error in sgpa
# SHASHANK AGASIMANI
# 7.50
# SMITHA K VENKATESH
# 9.17
# ABHISHEK SHIVAPPA HOSAMANI
# 9.50
# SURAJ BABASO DIVATE
# 8.34
# GANESH RAVINDRA VERNEKAR
# 8.50
# SUSHMA ASHOK SHIVANGOUDAR
# 8.34
# N SOUMYA
# 9.50
# PRANALI PRABHAKAR JADHAV
# 8.50
# B M SAI PRATHIK
# 8.17
# MAYURI K M
# 9.00
# PARAG RAVISH HEGDE
# 9.17
# ATREY MAHADEV ANAGAL
# 9.00
# YASHVARDHAN MAHESH DIWAN
# 9.50
# PRANAV BASAVANT JADHAV
# 8.50
# KIRAN DEVENDRAPPA MYAGERI
# Error in sgpa
# SAPTASAGAR SIDDHANT SHREEPAL
# Error in sgpa
# AKSHAY JOSHI
# 9.34
# BHOOMIKA VASANT KUMTA
# 8.50
# PRERANA SHETTI
# 8.50
# BODHA KANTESH KULKARNI
# 8.84
# VINAYAK SUDHAKAR KONE
# 9.50
# RAKSHITHA R T
# 9.25
# SWAROOP RAGHAVENDRA ANEGUNDI
# 9.34
# FIZA FEROZ KHAN
# 9.50
# SHIVANI PARAPPA HALEMANI
# 8.50
# AMRUTA A AYACHIT
# 8.67
# SUPREETH S KADAPPANAVAR
# 8.75
# BHARAT A JAIN
# 8.84
# PREETI GOURE
# 8.84
# PRAJAKTA KULKARNI
# 8.84
# KARTIK MANOJI KALAL
# 8.84
# DHIRAJ RAMESH BHANDARE
# 9.34
# PRANAVI PANDURANG KULKARNI
# 8.17
# APOORVA K KASIGAVI
# 9.40
# VITTAL B HUNDARAD
# 8.34
# NIKITA
# 7.50
# SHEETAL SHANTARAM GARAD
# Error in sgpa
# GAGANDEEP R LAMANI
# 8.00
# TRIVENI REVANASIDDAPPA KALWAD
# 9.00
# PRAVEEN ANIL DEVADKAR
# 9.00
# ROSHAN
# 8.17
# ANIKET GANESH PAI
# 8.84
# HARSHAKUMAR R HUNASHYAL
# 6.75
# T M GAGAN
# 7.50
# CHANDANA N G
# 7.50
# ABHAY P PATTAR
# 7.00
# SAHANA BASAVANTGOUDA KANTEPPAGOUDRA
# 9.00
# RAGHAVENDRA M K
# 8.34
# NEERAJ N K
# 8.84
# Error in name
# Error in sgpa
# PAVITHRA VASANADA
# 8.67
# SRISHTI ABBIGERI
# 8.84
# ANOOP PATIL
# 8.34
# SHRUTI NAGAPPA BAGODI
# 8.00
# NEEDA FATIMA ATTAR
# 9.34
# NEKKANTI SAIKEERTANA
# 8.67
# SWATI MALAGOUDA PATIL
# 8.00
# ADITYA PRAKASH NELLIKERI
# 7.00
# VISHWANATH YAMANUR BHAJANTRI
# 8.34
# SHREYAS JOSHI
# 9.00
# NEHA RAIKAR
# 8.50
# ABDUL MAJID MUJAHID
# 8.50
# ROHIT GOLABHAVI
# 8.17
# VARUN SHANKAR JAKANUR
# 8.50
# VINAYAK SIDRAMAYYANMATH
# 9.17
# KIRANKUMAR PATIL
# Error in sgpa
# KALAVATI TALLI
# 8.50
# TEJA M CHABBI
# 8.17
# AKASH V DALAWAYI
# 9.17
# JAHNAVI HALAWAI
# Error in sgpa
# BHIMRAO JAGADISH SHETTEPPAGOL
# 8.17
# OM VISHNUDAS PRABHU
# 9.34
# VINUTA S ARAMANI
# 9.34
# GURUTEJ R ABBIGERI
# 8.84
# ABHILASH DODDWAD
# 7.75
# VIJU RANGANNAVAR
# 8.60
# KAILASH ANGADI
# 8.17
# SWATI SADASHIV MUDAVI
# 8.84
# SANGAMESH PATIL
# 9.00
# SOHAM KAKADE
# 9.34
# PRAJWAL N SHAVI
# 9.00
# NEHA T PATIL
# 8.67
# YASH DESHPANDE
# 8.67
# OMSAI PRASAD GADGE
# 8.67
# SHANKARALING SHIVANAND HALEMANI
# 8.00
# VARUN PANDHARI
# 8.34
# TAFREEN Z HUSSIAN
# 8.17
# PAVANI PATIL
# 9.00
# SHRAVAN SANJAY NAYAK
# 8.00
# SANTOSH REDDY
# 9.00
# AVANI PATIL
# 8.67
# FAYAZ
# 7.00
# AKHILESH UTTAM GADAGKAR
# Error in sgpa
# NAGARAJ NAIK
# Error in sgpa
# SHREYAS SHRIKANT BHAT
# 8.17
# MANGESH DAYANAND SHANBHAG
# 8.00
# GURKIRAT SINGH
# 8.17
# RAMITA SAIRAM COMMI
# 9.17
# SANA RAZEEN G V
# 8.34
# LAVANYA SHAHAPUR
# 9.17
# SINDHU VIGHNESHWARA BHAT
# 9.00
# MADHURA K PATIL
# 8.67
# ANSHUL MISHRA
# 8.84
# PRAGATHI PUJARI
# 6.17
# Error in name
# Error in sgpa
# AZEEM MEHABOOB JALAGERI
# 8.34
# SOUMYA SHEKHAR GUTTIGOLI
# 9.17
# KIRAN CHANNABASAPPA NAREGAL
# 9.34
# UTKARSH KHOT
# 8.67
# Error in name
# Error in sgpa
# VAISHNAVI PATIL
# 9.20
# SHASHANK M HOSAPETI
# Error in sgpa
# AVINASH YUVARAJ P
# Error in sgpa
# BHARATH A KOLI
# 8.17
# SRUJAN B BASHETTI
# 8.17
# MICHAEL ROHAN SWAMINATHAN
# 9.50
# ADITI PRERNA
# 9.00
# APOORVA M ANGADI
# 8.84
# NISHANTH RAJESH NEGALI
# 8.67
# PRASANNAKUMAR BASAVARAJ ROOGI
# 6.17
# SURABHI SAINATH NAIK
# 8.67
# AAYUSHI GUPTA
# 7.75
# ASHWINI RAVIKIRAN JANNU
# Error in sgpa
# ANUSHA A PATIL
# 8.00
# BHUVI DINESH SANGAM
# 8.75
# SUYASH M KAMAT
# 8.84
# PRIYANSH RAJ
# 7.00
# NIKHIL DHUPADAL
# 8.67
# SAMEER AHMED ANKALAGI
# 7.17
# DARSHAN U DIXIT
# 7.84
# SHREYAS SHRIDHAR JAKATI
# 8.34
# SANJANA M DYAVAPPANAVAR
# 9.50
# SHRINIDHI P ALUR
# 8.50
# ANUSHA C CHIKKAMATH
# 9.50
# SANDESH S PATILKULKARNI
# 8.00
# VISHAL VIJAYKUMAR JOSHI
# Error in sgpa
# AMIT SANTOSH LADDIGATTI
# 9.34
# MANVANTH B S
# 8.84
# VAISHNAVI TORGAL
# 9.50
# SANJEEVINI GUNDAGATTI
# 7.00
# SRUJAN ITAGALLI
# 8.34
# SHRINIDHI R HIRERADDI
# 9.00
# VINAYAK MERAWADE
# 8.84
# SIDDARAJ S HUBBALLI
# 9.17
# ANIRUDH K
# 9.34
# SUMA DODDAMANI
# Error in sgpa
# PRAJWAL KAILASNATH PATIL
# 9.17
# ROHIT REDDY
# Error in sgpa
# Error in name
# Error in sgpa
# NAYANA D G
# 8.84
# H KAVANASHREE
# 8.84
# PRATIBHA LAGAMANNA HALYAL
# 5.00
# TEJAS G V
# 8.50
# M PRIYA
# 9.00
# ABHAY I SHIROL
# 9.50
# DHANARAJ K
# Error in sgpa
# HALLI HARSHITA
# 8.50
# Error in name
# Error in sgpa
# SAGAR SATISH KANAMADI
# 8.50
# Error in name
# Error in sgpa
# ROHIT DEVARANAVADAGI
# 8.84
# SHASHVI SRANIK JAIN
# 9.34
# ANAGHA A BENGERI
# 9.17
# HARSHA DESAI
# Error in sgpa
# PRATEEK KABADAR
# 9.00
# VISHAL FARANDE
# 8.25
# TANVI BHUJANNAVAR
# 8.34
# Error in name
# Error in sgpa
# RAHUL KUMAR THAKUR
# 7.34
# VAIBHAV KUMAR
# 7.84
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# SITANSHU S HALLAD
# 8.50
# Error in name
# Error in sgpa
# SATWIK KULKARNI
# 8.75
# VIVEK KUMAR
# 9.17
# Error in name
# Error in sgpa
# SIDHANT CHATURWEDI
# 6.37
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# SHUBHAM KUMAR
# 8.50
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# VIBHUTI RAJ
# 8.67
# Error in name
# Error in sgpa
# CHANDAN SRIVASTAVA B
# 9.17
# Error in name
# Error in sgpa
# CHIRAG S BIRADAR
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# ABHISHEK S MASUR
# 8.84
# Error in name
# Error in sgpa
# AKASH ARYAN
# 8.34
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# GUTTI BHARATH SAI
# Error in sgpa
# PALLAVI PRASHANT POTE
# 8.67
# SHASHANK DESAI
# Error in sgpa
# B AJAY KUSHAL
# 8.84
# ANANTHANENI SREEVALLI CHOWDARY
# 9.00
# SRISHTI SAURAV
# 8.84
# KANUMUKKALA JASWANTH REDDY
# 8.67
# AKSHATHRAJ N BHIMAKARI
# 8.17
# RISHABH CHOUDHARY
# 7.00
# PALAK JAIN
# 7.84
# SWASTIK VINOD NAYAK
# 8.17
# BALACHENNA VAIYBHAV REDDY
# Error in sgpa
# Error in name
# Error in sgpa
# PRIYAM KARN
# 8.00
# AKASH KUMAR
# 8.34
# NITIN KUMAR
# 8.67
# PRAKASH KUMAR SINGH
# 7.75
# RITIK KUMAR POONIA
# 8.50
# MOHIT GUMBER
# 8.20
# ANSH TIWARI
# 7.75
# Error in name
# Error in sgpa
# KISHANSMARAN PURANIK
# 9.34
# RAJATH V JANNU
# 8.84
# ATEETH K J
# 5.34
# ROHIT PATIL
# 9.25
# SHAKTI KUMAR SINGH
# 8.34
# NIKHIL PRAKASH PANDIT
# 9.00
# PRATEEK RENUKSWAMY BIDNURMATH
# Error in sgpa
# PATIL SHREEVATSA SHESHAGIRI
# 8.17
# PRARTHANA ODEYAR
# 8.34
# SHOURYA
# 8.67
# ANKIT M RAICHUR
# Error in sgpa
# ASHMIT SAXENA
# 7.17
# SHASTRANSH ROY
# 8.17
# SHIVAM SINGH
# 8.34
# SHARON GOTTIMUKKULA
# 0.00
# GANDLA HARSHITHA
# 8.84
# AMAN RAJ
# 8.50
# RISHAV PATTNAIK
# 7.84
# KARTIK PATIL
# 3.67
# KUSHAGRA PAREEK
# 8.00
# ANAND SAGAR
# 9.00
# NARENDRA VENKATA RAO THOTA
# 7.50
# PRIYANKA HUGAR
# Error in sgpa
# AMIT S NAMAVALI
# 0.00
# SANDESH C HIREMATH
# Error in sgpa
# SHREEDHAR IRANNA MUTTAGI
# Error in sgpa
# POOJA PUNDALIK BABAR
# 8.60
# SANJANA S HIREGOUDAR
# Error in sgpa
# PRANALI U HONGEKAR
# 8.40
# RAHUL RAJU PATIL
# Error in sgpa
# SHRINIDHI M BIRADAR
# Error in sgpa
# VIKAS E
# 8.75
# SIDDARTH R PATIL
# 7.20
# VEENASHRI VEERAPPA ANNIGERI
# Error in sgpa
# SOUMYA JITURI
# 8.80
# SACHIN SIDDANAGOUDA PATIL
# 9.00
# SANKALP BALANNAVAR
# 8.80
# MOEEZ KHAN A T
# Error in sgpa
# PRASAD R MUTNALE
# 8.50
# MANJUNATH DEVENDRAPPA PUJAR
# Error in sgpa
# ANURADHA B APTAGIRI
# Error in sgpa
# SANDEEP GANGADHAR URANKAR
# 9.50
# SRUSHTI LOKHANDE
# 9.00
# NASREEN
# 8.20
# SHRI NAGAHARI SAVANUR
# Error in sgpa
# RAVALI B
# Error in sgpa
# SWAROOP RAMESH MADIWALAR
# Error in sgpa
# AKSHATA SURESH KANAGOND
# Error in sgpa
# POOJA LINGARAJ HIREMANI
# Error in sgpa
# PREETI KUMBAR
# Error in sgpa
# MANASI SHARAN BYALI
# Error in sgpa
# JITHENDRA M
# 9.25
# SUPRIYA MANNUR
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa

# %%
file.close() #closing the file

# %%
import csv

# Read the CSV file
with open('result7_sgpa.csv', 'r') as infile:
    reader = csv.reader(infile)
    data = list(reader)  # Convert the data into a list of lists

# Sort the data based on the first column (index 0) as strings
sorted_data = sorted(data, key=lambda x: x[0])

# Save the sorted data to a new CSV file
with open('7sem.csv', 'w', newline='') as outfile:
    writer = csv.writer(outfile)
    writer.writerows(sorted_data)

print("CSV file sorted and saved as '7sem.csv'.")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [20], in <cell line: 9>()
#       6     data = list(reader)  # Convert the data into a list of lists
#       8 # Sort the data based on the first column (index 0) as strings
# ----> 9 sorted_data = sorted(data, key=lambda x: x[0])
#      11 # Save the sorted data to a new CSV file
#      12 with open('7sem.csv', 'w', newline='') as outfile:
#
# Input In [20], in <lambda>(x)
#       6     data = list(reader)  # Convert the data into a list of lists
#       8 # Sort the data based on the first column (index 0) as strings
# ----> 9 sorted_data = sorted(data, key=lambda x: x[0])
#      11 # Save the sorted data to a new CSV file
#      12 with open('7sem.csv', 'w', newline='') as outfile:
#
# IndexError: list index out of range

# %%
import csv

# Read the CSV file
with open('result7_sgpa.csv', 'r') as infile:
    reader = csv.reader(infile)
    data = list(reader)  # Convert the data into a list of lists

# Sort the data based on the first column (index 0) as strings, while handling empty rows
sorted_data = sorted(data, key=lambda x: x[0] if x and len(x) > 0 else '')

# Save the sorted data to a new CSV file
with open('7sem.csv', 'w', newline='') as outfile:
    writer = csv.writer(outfile)
    writer.writerows(sorted_data)

print("CSV file sorted and saved as '7sem.csv'.")
# Out:
# CSV file sorted and saved as '7sem.csv'.

# %%
import csv

# Read the CSV file
with open('result7_sgpa.csv', 'r') as infile:
    reader = csv.reader(infile)
    data = list(reader)  # Convert the data into a list of lists

# Sort the data based on the second column (index 1), converting values to numeric types
sorted_data = sorted(data, key=lambda x: float(x[1]) if x and len(x) > 1 else float('-inf'), reverse=True)

# Save the sorted data to a new CSV file
with open('7semTop.csv', 'w', newline='') as outfile:
    writer = csv.writer(outfile)
    writer.writerows(sorted_data)

print("CSV file sorted by the second column in descending order and saved as '7sem.csv'.")
# Out:
# CSV file sorted by the second column and saved as '7sem.csv'.
